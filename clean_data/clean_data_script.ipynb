# %%
import pandas as pd
import numpy as np

# %%
ri_matches = pd.read_csv('../dataset/ri_matches_awards_2024-12-8_3-53-3.csv')
print(ri_matches.head())
# Out:
#    awardgoverningsocietyid                          awardgoverningsocietyname  \
# 0                     3022                                      Sacred Writes
# 1                     1460  United States Department of State, Bureau of E...
# 2                      234        National Endowment for the Humanities (NEH)
# 3                     2577                               Corporation of Yaddo
# 4                     2222                                   MacDowell Colony
#
#    awardid                               awardname  awardreceivedid  \
# 0    17602  Public Scholarship Training Fellowship          1360881
# 1     1786                       Fulbright Scholar          1012987
# 2     2147                  Summer Stipends Awards           334146
# 3    14901                         Yaddo Residency          1123551
# 4    12639                   MacDowell Fellowships          1122487
#
#   awardreceivedname  awardreceivedawardyear  AAUID clientfacultyid orcid  \
# ...

# %%
discipline = pd.read_csv('../dataset/Discipline Specific Pathways.csv', encoding='latin-1')
print(discipline.head())
# Out:
#                                        | Focal Award            | Discipline  \
# 0        A-T Children's Project | AT Research Grants               Pathology
# 1        A-T Children's Project | AT Research Grants               Pathology
# 2  Abdullah bin Hamad Al-Attiyah International Fo...    Engineering, various
# 3  Abdullah bin Hamad Al-Attiyah International Fo...    Engineering, various
# 4  Abdullah bin Hamad Al-Attiyah International Fo...  Environmental Sciences
#
#                                      | Pathway Award  \
# 0  Association for Molecular Pathology | AMP Youn...
# 1        A-T Children's Project | AT Research Grants
# 2  Society of Petroleum Engineers | Health, Safet...
# 3  Geological Society of America, The | Michel T ...
# 4  Society of Petroleum Engineers | Health, Safet...
#
#    | # Awardees w/ This Award | Percentage of Awardees with This Award  \
# 0                           1                                  100.00%
# ...
